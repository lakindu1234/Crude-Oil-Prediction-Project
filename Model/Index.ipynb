# %%
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("crude-oil-price.csv")

# %%
df
# Out:
#                           date    price  percentChange   change
# 0    1983-03-01 00:00:00+00:00  29.2700            NaN      NaN
# 1    1983-04-01 00:00:00+00:00  30.6300          4.646   1.3600
# 2    1983-05-01 00:00:00+00:00  30.2500         -1.241  -0.3800
# 3    1983-06-01 00:00:00+00:00  31.3800          3.736   1.1300
# 4    1983-07-01 00:00:00+00:00  32.0000          1.976   0.6200
# ..                         ...      ...            ...      ...
# 505  2025-04-01 00:00:00+00:00  58.2100        -18.565 -13.2700
# 506  2025-05-01 00:00:00+00:00  60.7900          4.432   2.5800
# 507  2025-06-01 00:00:00+00:00  65.1100          7.106   4.3200
# 508  2025-07-01 00:00:00+00:00  69.2600          6.374   4.1500
# 509  2025-08-01 00:00:00+00:00  63.7646         -7.934  -5.4954
#
# [510 rows x 4 columns]

# %%
df.describe()
# Out:
#             price  percentChange      change
# count  510.000000     509.000000  509.000000
# mean    46.767957       0.682509    0.067769
# std     28.847577      10.414884    4.961357
# min     10.420000     -54.245000  -32.830000
# 25%     20.530000      -5.332000   -1.740000
# 50%     35.775000       0.929000    0.270000
# 75%     69.682500       6.278000    2.400000
# max    140.000000      88.376000   16.650000

# %%
df.isnull().sum()
# Out:
# date             0
# price            0
# percentChange    1
# change           1
# dtype: int64

# %%
df["percentChange"] = df["percentChange"].fillna(df["percentChange"].median())

# %%
df["change"] = df["change"].fillna(df["change"].median())

# %%
df.isnull().sum()
# Out:
# date             0
# price            0
# percentChange    0
# change           0
# dtype: int64

# %%
df
# Out:
#                           date    price  percentChange   change
# 0    1983-03-01 00:00:00+00:00  29.2700          0.929   0.2700
# 1    1983-04-01 00:00:00+00:00  30.6300          4.646   1.3600
# 2    1983-05-01 00:00:00+00:00  30.2500         -1.241  -0.3800
# 3    1983-06-01 00:00:00+00:00  31.3800          3.736   1.1300
# 4    1983-07-01 00:00:00+00:00  32.0000          1.976   0.6200
# ..                         ...      ...            ...      ...
# 505  2025-04-01 00:00:00+00:00  58.2100        -18.565 -13.2700
# 506  2025-05-01 00:00:00+00:00  60.7900          4.432   2.5800
# 507  2025-06-01 00:00:00+00:00  65.1100          7.106   4.3200
# 508  2025-07-01 00:00:00+00:00  69.2600          6.374   4.1500
# 509  2025-08-01 00:00:00+00:00  63.7646         -7.934  -5.4954
#
# [510 rows x 4 columns]

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df
# Out:
#                          date    price  percentChange   change  year  month
# 0   1983-03-01 00:00:00+00:00  29.2700          0.929   0.2700  1983      3
# 1   1983-04-01 00:00:00+00:00  30.6300          4.646   1.3600  1983      4
# 2   1983-05-01 00:00:00+00:00  30.2500         -1.241  -0.3800  1983      5
# 3   1983-06-01 00:00:00+00:00  31.3800          3.736   1.1300  1983      6
# 4   1983-07-01 00:00:00+00:00  32.0000          1.976   0.6200  1983      7
# ..                        ...      ...            ...      ...   ...    ...
# 505 2025-04-01 00:00:00+00:00  58.2100        -18.565 -13.2700  2025      4
# 506 2025-05-01 00:00:00+00:00  60.7900          4.432   2.5800  2025      5
# 507 2025-06-01 00:00:00+00:00  65.1100          7.106   4.3200  2025      6
# 508 2025-07-01 00:00:00+00:00  69.2600          6.374   4.1500  2025      7
# 509 2025-08-01 00:00:00+00:00  63.7646         -7.934  -5.4954  2025      8
#
# [510 rows x 6 columns]

# %%
df.drop(['date'], axis=1, inplace=True)
df.head()
# Out:
#    price  percentChange  change  year  month
# 0  29.27          0.929    0.27  1983      3
# 1  30.63          4.646    1.36  1983      4
# 2  30.25         -1.241   -0.38  1983      5
# 3  31.38          3.736    1.13  1983      6
# 4  32.00          1.976    0.62  1983      7

# %%
df.drop(['percentChange', 'change'], axis=1, inplace=True)
df.head()
# Out:
#    price  year  month
# 0  29.27  1983      3
# 1  30.63  1983      4
# 2  30.25  1983      5
# 3  31.38  1983      6
# 4  32.00  1983      7

# %%
df.shape
# Out:
# (510, 3)

# %%
df.isnull().sum()
# Out:
# price    0
# year     0
# month    0
# dtype: int64

# %%
x = df[['year', 'month']]
y = df['price']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# %%
df
# Out:
#        price  year  month
# 0    29.2700  1983      3
# 1    30.6300  1983      4
# 2    30.2500  1983      5
# 3    31.3800  1983      6
# 4    32.0000  1983      7
# ..       ...   ...    ...
# 505  58.2100  2025      4
# 506  60.7900  2025      5
# 507  65.1100  2025      6
# 508  69.2600  2025      7
# 509  63.7646  2025      8
#
# [510 rows x 3 columns]

# %%
x.head()
# Out:
#    year  month
# 0  1983      3
# 1  1983      4
# 2  1983      5
# 3  1983      6
# 4  1983      7

# %%
y.head()
# Out:
# 0    29.27
# 1    30.63
# 2    30.25
# 3    31.38
# 4    32.00
# Name: price, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
x_future = np.array([[2000, 12]])   # 2D array
model.predict(x_future)
# Out:
# c:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41.44989151])

# %%
model.score(x_test, y_test)
# Out:
# 0.47941426801923215

# %%
model.score(x_train, y_train)
# Out:
# 0.535863153255858

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# Example with two models
models = {
    "Linear Regression": LinearRegression(),
    "Random Forest": RandomForestRegressor(random_state=42)
}

for name, model in models.items():
    model.fit(x_train, y_train)
    score = model.score(x_test, y_test)  # This gives R² score
    print(f"{name}: Score = {score:.4f}")
# Out:
# Linear Regression: Score = 0.4794
# Random Forest: Score = 0.9623
